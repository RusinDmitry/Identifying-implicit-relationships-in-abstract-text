# %%
# !git clone https://github.com/RusinDmitry/Identifying-implicit-relationships-in-abstract-text
# Out:
# Cloning into 'Identifying-implicit-relationships-in-abstract-text'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 71 (delta 35), reused 47 (delta 24), pack-reused 3
# Receiving objects: 100% (71/71), 5.59 MiB | 10.25 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %% [markdown]
# ## Импортирование данных

# %%
import pandas as pd
import numpy as np
clusters = pd.read_csv("/content/Identifying-implicit-relationships-in-abstract-text/clusters.csv")

# %% [markdown]
# ## Разбиение кластеров по классам. Остальные попадают в прочее

# %%
classes = {"Дата выхода": [57, 52],
 "Контингент (индификатор)": [33, 89, 58, 91, 75],
 "Цена": [49, 55, 56, 73, 85, 79, 53],
 "Название проекта (Описание)": [3, 5, 34, 7, 12, 19, 83, 76, 14, 61, 22, 25, 43, 48, 6, 41, 24, 95, 23, 6, 41, 43, 29, 51, 4, 62, 90, 1, 40, 27, 81, 21,  81, 38, 71, 86, 16, 54],
 "Производитель, разработчик": [35, 13, 44, 74],
 "Покупатель, заказчик": [0, 42],
 "Участник торгов": [93, 63, 20]}
classes["Прочее"] = list(set(range(0, 100)) - set(sum(list(classes.values()), [])))


df_list = []
for index, row in clusters.iterrows():
    text_list = row.iloc[0]
    text = eval(text_list)
    class_ = np.full(shape = len(text), fill_value=row.iloc[1])
    df = pd.DataFrame({"text": text, "label": class_})
    df_list.append(df)


data = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# Замена номеров кластеров на метки класса. Сохранение файла

# %%
data2 = data.copy()
data2['label'] = data2['label'].astype(str)
for key, value in classes.items():
    for dig in value:
        data2['label'] = data2['label'].str.replace(r"\b"+str(dig)+r"\b", key, regex=True)

data2.to_csv("dataset.csv", index=False)

# %%
data2
# Out:
#                                                    text  \
# 0
# 1                                                     /
# 2                                                  Нет.
# 3                                                    /.
# 4                                                     .
# ...                                                 ...
# 9623  Закупка шкафов безопасности DCS-системы малого...
# 9624  Проект: Закупка шкафов безопасности для малома...
# 9625  Закупка шкафов безопасности системы управления...
# 9626  Закупка незащищенных шкафов для маломасштабной...
# 9627  Проект: Закупка незащищенных шкафов для малома...
#
#                             label
# 0                          Прочее
# 1                          Прочее
# 2                          Прочее
# 3                          Прочее
# 4                          Прочее
# ...                           ...
# 9623  Название проекта (Описание)
# 9624  Название проекта (Описание)
# ...
